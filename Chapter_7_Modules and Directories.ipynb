# %% [markdown]
# #  Modules
# - A module is a file consisting of a python coden. It can have classes, variables, and functions.
# - There are two types of modules:-
#     -python inbuilt modules
#     -user defined modules

# %% [markdown]
# ## Python inbuild modules
# - These modules comes with python installation. They can be used directly importing them

# %% [markdown]
# ## import
# - To use the module functions, it has to be imported first. It is imported using `import` statement

# %%
import math

# %%
print(math.pi)

# %%
math.cos(2*math.pi)

# %% [markdown]
# ## alternative way - `NOT RECOMMENDED`

# %%
# from math import *

# %%
print(pi)

# %%
print(cos(3))

# %%
print(cos(pi))

# %% [markdown]
# ## alternative method - import only that is needed

# %%
from math import pi,cos

# %%
print(pi)

# %%
print(sin(3))

# %% [markdown]
# ## import using aliases

# %%
from math import cos as cosine, pi as pieee

# %%
cosine(pieee)

# %%
cos(pi)

# %%
help(cosine)

# %% [markdown]
# ##  Userdefined modules

# %%
# %%writefile myfile.py
a = 100
b = 400
s = "hello World"

# %%
print(a)

# %%
import myfile

# %%
print(myfile.a)

# %%
print(myfile.b)

# %%
print(myfile.s)

# %%
from myfile import s as mystring

# %%
print(s)

# %%
print(myfile.s)

# %%
print(mystring)

# %%
from myfile import a,b,s

# %%
print(myfile.b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-082a661729f0> in <module>
# ----> 1 print(myfile.b)
#
# NameError: name 'myfile' is not defined

# %%
print(myfile.a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-e72eab1a419a> in <module>
# ----> 1 print(myfile.a)
#
# NameError: name 'myfile' is not defined

# %%
print(a,b,s)
# Out:
# 100 400 hello World

# %%
from myfile import *

# %%
print(myfile.a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-e72eab1a419a> in <module>
# ----> 1 print(myfile.a)
#
# NameError: name 'myfile' is not defined

# %%
print(a)
# Out:
# 100

# %% [markdown]
# ## Python `OS` Module
# - ***This module provides functions for creating, removing, updating, fetching and identifying directories within the host operating system(os)***

# %% [markdown]
# ## Check the current working directories

# %%
import os

# %%
os.getcwd()
# Out:
# 'D:\\121_T3_Python'

# %% [markdown]
# ## Listing the directories

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'alice1.txt',
#  'anewfile.txt',
#  'Chapter_6  File Handling (10 Marks).ipynb',
#  'Chapter_7_Modules and Directories.ipynb',
#  'customer.txt',
#  'example.txt',
#  'example1.txt',
#  'example2.txt',
#  'file2.txt',
#  'file3.txt',
#  'friends.txt',
#  'hello.txt',
#  'hello1.txt',
#  'IMP.ipynb',
#  'longfile.txt',
#  'magicfile.txt',
#  'mbox-short.txt',
#  'myfile.py',
#  'newmagicfile.txt',
#  'odd.txt',
#  'PB_Python-I_SEM III_2025.pdf',
#  'random.txt',
#  'sample.txt',
#  'sample1.txt',
#  'sample2.txt',
#  'SEM III_FCSP-1_CE_Syllabus.pdf',
#  'smile.txt',
#  'urdu.txt',
#  '__pycache__']

# %% [markdown]
# # Creating a directories

# %%
os.mkdir("Mydirectory")

# %% [markdown]
# ##  Creating a nested directories

# %%
os.makedirs("newone/another")

# %% [markdown]
# ## Removing a directory
# - for removing, it must be noted that the directory is empty

# %%
os.rmdir("newone")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-14-5d18f6a8d629> in <module>
# ----> 1 os.rmdir("newone")
#
# OSError: [WinError 145] The directory is not empty: 'newone'

# %%
os.rmdir("newone/another") # it removes another named folder
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-16-96ce91911f1d> in <module>
# ----> 1 os.rmdir("newone/another")
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'newone/another'

# %%
os.rmdir("newone")

# %% [markdown]
# ##  Change working directory

# %%
os.chdir("D://")

# %%
os.getcwd()
# Out:
# 'D:\\'

# %%
os.remove??

# %%
pwd
# Out:
# 'D:\\'

# %%
os.remove("hello.txt")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-24-966e58ed761d> in <module>
# ----> 1 os.remove("hello.txt")
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'hello.txt'

# %%
# %%writefile hello.py
print("hello world")
# Out:
# Writing hello.py

# %%
import hello
# Out:
# hello world

# %%
import hello

# %% [markdown]
# # PB-496
# ```
#  Write a python program to make a module which contain all the basic functions related to string and import that module in another file and use that fuctions with string given by user.
# -reverse
# -chaactercount
# ```

# %%
# %%writefile stringmodule.py
def reversestring(inputstring):
    return inputstring[::-1]
def charactercount(inputstring):
    return len(inputstring) - inputstring.count(" ")
# Out:
# Overwriting stringmodule.py

# %%
from stringmodule import reversestring,charactercount

# %%
reversestring("This is Python")
# Out:
# 'nohtyP si sihT'

# %%
charactercount("This is python")
# Out:
# 12

# %% [markdown]
# # PB-497  Write a python program to create a directory and subdirectory. It should print the current working directory path and list of names of files present in the given directory

# %%
import os

# %%
os.makedirs("folder-11/folder-11.1")

# %%
os.getcwd()
# Out:
# 'D:\\'

# %% [markdown]
# #  PB-498 : Write a python program to make a module named cal.py which contain all the basic functions related to calculator like addition, subtraction, multiplication, and division import that module in another file and use that functions with number inputs given by user.

# %%
# %%writefile cal.py
def add(x,y):
    return x+y
def sub(x,y):
    return x-y
def mul(x,y):
    return x*y 
def div(x,y):
    return x/y
# Out:
# Overwriting cal.py
